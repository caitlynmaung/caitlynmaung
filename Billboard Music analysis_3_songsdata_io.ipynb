# %%
import time
import requests
from datetime import datetime
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = "https://www.billboard.com/charts/hot-100/"

# %%
# calculate last day of the month
def get_last_day_of_month(year, month):
    last_days = [31, 30, 29, 28, 27] # options for last day
    for i in last_days:
        try:
            end = datetime(year, month, i)
        except ValueError:
            continue
        else:
            return end.date()

# %%
# get the billboards url for the last week of a specific month
def get_top_100_url(year, month):
    last_day = get_last_day_of_month(year, month)
    url = f"https://www.billboard.com/charts/hot-100/{last_day}/" # find the url for the last week of the month (last day input works great)
    return url

# %%
# out of the 100, use html parsing to find the top 10 songs in particular
def get_top_10_songs(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        song_entries = soup.find_all('ul', class_='o-chart-results-list-row') # specific tag we need to find
        top_10_songs = [] # store all the data found in a list for later reference

        for entry in song_entries[:10]: # go through all of these items
            title_tag = entry.find('h3', id='title-of-a-story') # find the h3 tag in the data (contains title of songs)
            # find the span tag in the data (contains artists)
            artist_tags = entry.find_all('span', class_='c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only')
            song_title = title_tag.text.strip() # formatting of string
            artists = ' & '.join([artist.text.strip() for artist in artist_tags]) # join together all artists but separate by "&" to distinguish separate names
            song_info = song_title + artists # combine to give our query
            song_info = song_info.replace("Featuring","") # delete filler words that may be found in the string
            top_10_songs.append(song_info) # add this to our list

        return top_10_songs

    else:
        print(f"Error fetching {url}: Status code {response.status_code}") # if the url is not found (no issues!)
        return []

# %%
# now we want to get access the appropriate url from songdata.io
def get_songdata_url(song):
    search_url = f"https://songdata.io/search?query={'+'.join(song.split())}" # let us split our query string into words that are joined by "+" (noted from url of search queries)
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    response = requests.get(search_url, headers=headers) # grab response

    if response.status_code == 200: # if data found!
        soup = BeautifulSoup(response.text, 'html.parser') # parse
        first_td = soup.find('td', class_='table_name') # find the first table with this class
        if first_td:
            link_tag = first_td.find('a') # then find the first <a></a> tag within the <td></td> tags
            if link_tag:
                song_url = 'https://songdata.io' + link_tag.get('href') # then lets concactenate to find the full url
                return song_url

    print(f"No Songdata URL found for {song}") # if the url is not found
    return None

# %%
# get the audio features locations in the songdata.io url for each song (runs for input feature to avoid repetition of code for each separate feature)

def get_feature_value(soup, feature_name):
    time.sleep(0.2) # extensive rate-limiting while scraping normally so need to pause execution (0.2 minimum value helped us reach 1 hour runtime)
    if feature_name == "BPM": # BPM's are in a unique location
      bpm_dl = soup.find('dl', class_='card grid my-1 py-1') # find <dl> tag
      if bpm_dl:
          bpm_dd = bpm_dl.find('dd', style='font-size:1.5rem;font-weight:600;margin:0') # find nesting <dd> tag
          if bpm_dd:
              bpm_val = bpm_dd.text.strip() # format string appropriately
              return float(bpm_val) # return as a float to allow average calculations later on

      print("BPM not found in song.") # if bpm not found (no issues!)
      return None

    feature_dt = soup.find('dt', string=feature_name) # for all other features find <dt> tag
    if feature_dt:
        feature_dd = feature_dt.find_next_sibling('dd') # find nested <dd> tag
        if feature_dd:
            feature_val = feature_dd.text.strip() # format string appropriately
            return float(feature_val.replace('%', '').strip()) # remove character "%" since we want float value

    print(f"{feature_name} not found in song.") # if feature is not found
    return None

# %%
# no call to find the individual feature values
def get_features_for_song(song_url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    response = requests.get(song_url, headers=headers)

    if response.status_code == 200: # if response found
        soup = BeautifulSoup(response.text, 'html.parser') # parse!
        features = { # create dictionary to store all feature data
            "Acousticness": get_feature_value(soup, "Acousticness"), # for this feature, call get_feature_value to get value
            "Danceability": get_feature_value(soup, "Danceability"), # do the same for each feature
            "Energy": get_feature_value(soup, "Energy"),
            "Instrumentalness": get_feature_value(soup, "Instrumentalness"),
            "BPM": get_feature_value(soup, "BPM")
        }
        return features

    print(f"Error fetching features for {song_url}") # if the url is not found
    return None

# %%
# overarching function to run for selected time range (2010 to 2023)
def collect_data(start_year, end_year):
    audio_data = {}
    for year in range(start_year, end_year + 1): # need to add 1 to end_year to run through 2023 data
        for month in range(1, 13): # run through all 12 months
            last_day = get_last_day_of_month(year, month)
            month_str = last_day.strftime('%Y-%m-%d') # format string

            top_100_url = get_top_100_url(year, month) # get our top 100 per week

            top_10_songs = get_top_10_songs(top_100_url) # get our top 10 per week

            song_data_urls = [] # store all urls here!

            for song in top_10_songs: # per song
                song_url = get_songdata_url(song) # get our songdata.io url
                if song_url:
                    song_data_urls.append(song_url) # store this url
                else:
                    song_data_urls.append(None)

            features_data = [] # store all feature data here!
            for song_url in song_data_urls: # go through all urls
                if song_url:
                    features = get_features_for_song(song_url) # find feature data for each song
                    if features:
                        features_data.append(features) # store

            if features_data:

                avg_features = {} # average our features!
                for feature in features_data[0].keys(): # lets go through the keys for each index in features_data
                    avg_features[feature] = (sum([f[feature] for f in features_data]) / len(features_data))/100 # then find the average of these features

                audio_data[month_str] = avg_features # add this information to our overarching audio_data dictionary
                print(f"Average features for {month_str}: {avg_features}") # print for runtime updates
            else:
                audio_data[month_str] = {feature: None for feature in ["Danceability", "Energy", "Loudness", "Tempo", "Acousticness"]} # otherwise input None

    return audio_data

def create_dataframe(start_year, end_year): # now create our dataframe (using Pandas) for easy plotting!
    audio_data = collect_data(start_year, end_year) # input our start and end years
    df = pd.DataFrame(audio_data).T # transpose to get features as column values
    return df

df = create_dataframe(2010, 2023) # call
# Out:
# Average features for 2010-01-31: {'Acousticness': 0.198, 'Danceability': 0.7390000000000001, 'Energy': 0.71, 'Instrumentalness': 0.086, 'BPM': 1.23}
# Average features for 2010-02-28: {'Acousticness': 0.13, 'Danceability': 0.794, 'Energy': 0.57, 'Instrumentalness': 0.0, 'BPM': 1.09}
# Average features for 2010-03-31: {'Acousticness': 0.175, 'Danceability': 0.73, 'Energy': 0.7390000000000001, 'Instrumentalness': 0.085, 'BPM': 1.213}
# Average features for 2010-04-30: {'Acousticness': 0.14300000000000002, 'Danceability': 0.727, 'Energy': 0.7140000000000001, 'Instrumentalness': 0.0, 'BPM': 1.182}
# Average features for 2010-05-31: {'Acousticness': 0.17300000000000001, 'Danceability': 0.685, 'Energy': 0.779, 'Instrumentalness': 0.09699999999999999, 'BPM': 1.1340000000000001}
# Average features for 2010-06-30: {'Acousticness': 0.187, 'Danceability': 0.7240000000000001, 'Energy': 0.752, 'Instrumentalness': 0.01, 'BPM': 1.031}
# Average features for 2010-07-31: {'Acousticness': 0.14800000000000002, 'Danceability': 0.737, 'Energy': 0.7190000000000001, 'Instrumentalness': 0.09300000000000001, 'BPM': 1.079}
# Average features for 2010-08-31: {'Acousticness': 0.15, 'Danceability': 0.659, 'Energy': 0.66, 'Instrumentalness': 0.126, 'BPM': 1.054}
# Average features for 2010-09-30: {'Acousticness': 0.158, 'Danceability': 0.669, 'Energy': 0.7120000000000001, 'Instrumentalness': 0.003, 'BPM': 1.246}
# Average features for 2010-10-31: {'Acousticness': 0.13699999999999998, 'Danceability': 0.657, 'Energy': 0.66, 'Instrumentalness': 0.057999999999999996, 'BPM': 1.207}
# Average features for 2010-11-30: {'Acousticness': 0.081, 'Danceability': 0.636, 'Energy': 0.7559999999999999, 'Instrumentalness': 0.055, 'BPM': 1.27}
# Average features for 2010-12-31: {'Acousticness': 0.138, 'Danceability': 0.711, 'Energy': 0.65, 'Instrumentalness': 0.055, 'BPM': 1.217}
# Average features for 2011-01-31: {'Acousticness': 0.15, 'Danceability': 0.69, 'Energy': 0.792, 'Instrumentalness': 0.017, 'BPM': 1.215}
# Average features for 2011-02-28: {'Acousticness': 0.10800000000000001, 'Danceability': 0.6759999999999999, 'Energy': 0.759, 'Instrumentalness': 0.005, 'BPM': 1.195}
# Average features for 2011-03-31: {'Acousticness': 0.188, 'Danceability': 0.7070000000000001, 'Energy': 0.6940000000000001, 'Instrumentalness': 0.005, 'BPM': 1.2670000000000001}
# Average features for 2011-04-30: {'Acousticness': 0.201, 'Danceability': 0.669, 'Energy': 0.75, 'Instrumentalness': 0.005, 'BPM': 1.335}
# Average features for 2011-05-31: {'Acousticness': 0.223, 'Danceability': 0.7120000000000001, 'Energy': 0.669, 'Instrumentalness': 0.0, 'BPM': 1.2930000000000001}
# Average features for 2011-06-30: {'Acousticness': 0.17600000000000002, 'Danceability': 0.6729999999999999, 'Energy': 0.705, 'Instrumentalness': 0.0, 'BPM': 1.3230000000000002}
# Average features for 2011-07-31: {'Acousticness': 0.23399999999999999, 'Danceability': 0.635, 'Energy': 0.653, 'Instrumentalness': 0.0, 'BPM': 1.212}
# Average features for 2011-08-31: {'Acousticness': 0.195, 'Danceability': 0.758, 'Energy': 0.5920000000000001, 'Instrumentalness': 0.0, 'BPM': 1.072}
# Average features for 2011-09-30: {'Acousticness': 0.24600000000000002, 'Danceability': 0.685, 'Energy': 0.615, 'Instrumentalness': 0.0, 'BPM': 1.107}
# Average features for 2011-10-31: {'Acousticness': 0.298, 'Danceability': 0.679, 'Energy': 0.626, 'Instrumentalness': 0.057, 'BPM': 1.268}
# Average features for 2011-11-30: {'Acousticness': 0.255, 'Danceability': 0.7120000000000001, 'Energy': 0.613, 'Instrumentalness': 0.057, 'BPM': 1.193}
# Average features for 2011-12-31: {'Acousticness': 0.198, 'Danceability': 0.6970000000000001, 'Energy': 0.682, 'Instrumentalness': 0.057, 'BPM': 1.244}
# Average features for 2012-01-31: {'Acousticness': 0.14400000000000002, 'Danceability': 0.688, 'Energy': 0.7, 'Instrumentalness': 0.0, 'BPM': 1.1520000000000001}
# Average features for 2012-02-29: {'Acousticness': 0.192, 'Danceability': 0.6559999999999999, 'Energy': 0.728, 'Instrumentalness': 0.0, 'BPM': 1.193}
# Average features for 2012-03-31: {'Acousticness': 0.145, 'Danceability': 0.742, 'Energy': 0.645, 'Instrumentalness': 0.066, 'BPM': 1.1640000000000001}
# Average features for 2012-04-30: {'Acousticness': 0.309, 'Danceability': 0.74, 'Energy': 0.696, 'Instrumentalness': 0.0, 'BPM': 1.266}
# Average features for 2012-05-31: {'Acousticness': 0.304, 'Danceability': 0.76, 'Energy': 0.6859999999999999, 'Instrumentalness': 0.0, 'BPM': 1.272}
# Average features for 2012-06-30: {'Acousticness': 0.26899999999999996, 'Danceability': 0.701, 'Energy': 0.6609999999999999, 'Instrumentalness': 0.0, 'BPM': 1.213}
# Average features for 2012-07-31: {'Acousticness': 0.168, 'Danceability': 0.6729999999999999, 'Energy': 0.7140000000000001, 'Instrumentalness': 0.068, 'BPM': 1.146}
# Average features for 2012-08-31: {'Acousticness': 0.257, 'Danceability': 0.631, 'Energy': 0.741, 'Instrumentalness': 0.068, 'BPM': 1.1179999999999999}
# Average features for 2012-09-30: {'Acousticness': 0.152, 'Danceability': 0.6459999999999999, 'Energy': 0.742, 'Instrumentalness': 0.0, 'BPM': 1.0979999999999999}
# Average features for 2012-10-31: {'Acousticness': 0.168, 'Danceability': 0.623, 'Energy': 0.7140000000000001, 'Instrumentalness': 0.0, 'BPM': 1.091}
# Average features for 2012-11-30: {'Acousticness': 0.12300000000000001, 'Danceability': 0.6970000000000001, 'Energy': 0.622, 'Instrumentalness': 0.0, 'BPM': 1.084}
# Average features for 2012-12-31: {'Acousticness': 0.066, 'Danceability': 0.698, 'Energy': 0.648, 'Instrumentalness': 0.0, 'BPM': 1.037}
# Average features for 2013-01-31: {'Acousticness': 0.045, 'Danceability': 0.7140000000000001, 'Energy': 0.612, 'Instrumentalness': 0.008, 'BPM': 1.124}
# Average features for 2013-02-28: {'Acousticness': 0.226, 'Danceability': 0.6729999999999999, 'Energy': 0.519, 'Instrumentalness': 0.0, 'BPM': 1.131}
# Average features for 2013-03-31: {'Acousticness': 0.23399999999999999, 'Danceability': 0.682, 'Energy': 0.519, 'Instrumentalness': 0.0, 'BPM': 1.067}
# Average features for 2013-04-30: {'Acousticness': 0.242, 'Danceability': 0.638, 'Energy': 0.597, 'Instrumentalness': 0.0, 'BPM': 1.193}
# Average features for 2013-05-31: {'Acousticness': 0.252, 'Danceability': 0.662, 'Energy': 0.6409999999999999, 'Instrumentalness': 0.0, 'BPM': 1.097}
# Average features for 2013-06-30: {'Acousticness': 0.131, 'Danceability': 0.684, 'Energy': 0.664, 'Instrumentalness': 0.006, 'BPM': 1.185}
# Average features for 2013-07-31: {'Acousticness': 0.134, 'Danceability': 0.7020000000000001, 'Energy': 0.605, 'Instrumentalness': 0.098, 'BPM': 1.24}
# Average features for 2013-08-31: {'Acousticness': 0.192, 'Danceability': 0.698, 'Energy': 0.598, 'Instrumentalness': 0.19, 'BPM': 1.246}
# Average features for 2013-09-30: {'Acousticness': 0.19, 'Danceability': 0.6679999999999999, 'Energy': 0.5660000000000001, 'Instrumentalness': 0.20800000000000002, 'BPM': 1.151}
# Average features for 2013-10-31: {'Acousticness': 0.14800000000000002, 'Danceability': 0.654, 'Energy': 0.677, 'Instrumentalness': 0.094, 'BPM': 1.242}
# Average features for 2013-11-30: {'Acousticness': 0.129, 'Danceability': 0.675, 'Energy': 0.631, 'Instrumentalness': 0.002, 'BPM': 1.071}
# Average features for 2013-12-31: {'Acousticness': 0.16, 'Danceability': 0.629, 'Energy': 0.674, 'Instrumentalness': 0.002, 'BPM': 1.127}
# Average features for 2014-01-31: {'Acousticness': 0.121, 'Danceability': 0.613, 'Energy': 0.672, 'Instrumentalness': 0.0, 'BPM': 1.146}
# Average features for 2014-02-28: {'Acousticness': 0.087, 'Danceability': 0.68, 'Energy': 0.68, 'Instrumentalness': 0.0, 'BPM': 1.095}
# Average features for 2014-03-31: {'Acousticness': 0.08199999999999999, 'Danceability': 0.733, 'Energy': 0.622, 'Instrumentalness': 0.0, 'BPM': 1.043}
# Average features for 2014-04-30: {'Acousticness': 0.152, 'Danceability': 0.696, 'Energy': 0.616, 'Instrumentalness': 0.001, 'BPM': 1.14}
# Average features for 2014-05-31: {'Acousticness': 0.182, 'Danceability': 0.7070000000000001, 'Energy': 0.606, 'Instrumentalness': 0.08800000000000001, 'BPM': 1.159}
# Average features for 2014-06-30: {'Acousticness': 0.129, 'Danceability': 0.713, 'Energy': 0.755, 'Instrumentalness': 0.001, 'BPM': 1.175}
# Average features for 2014-07-31: {'Acousticness': 0.067, 'Danceability': 0.752, 'Energy': 0.72, 'Instrumentalness': 0.11699999999999999, 'BPM': 1.212}
# Average features for 2014-08-31: {'Acousticness': 0.094, 'Danceability': 0.752, 'Energy': 0.682, 'Instrumentalness': 0.087, 'BPM': 1.197}
# Average features for 2014-09-30: {'Acousticness': 0.106, 'Danceability': 0.752, 'Energy': 0.688, 'Instrumentalness': 0.087, 'BPM': 1.177}
# Average features for 2014-10-31: {'Acousticness': 0.10800000000000001, 'Danceability': 0.71, 'Energy': 0.662, 'Instrumentalness': 0.087, 'BPM': 1.234}
# Average features for 2014-11-30: {'Acousticness': 0.126, 'Danceability': 0.745, 'Energy': 0.618, 'Instrumentalness': 0.0, 'BPM': 1.128}
# Average features for 2014-12-31: {'Acousticness': 0.193, 'Danceability': 0.711, 'Energy': 0.601, 'Instrumentalness': 0.0, 'BPM': 1.187}
# Average features for 2015-01-31: {'Acousticness': 0.22699999999999998, 'Danceability': 0.736, 'Energy': 0.633, 'Instrumentalness': 0.0, 'BPM': 1.1909999999999998}
# Average features for 2015-02-28: {'Acousticness': 0.319, 'Danceability': 0.672, 'Energy': 0.601, 'Instrumentalness': 0.0, 'BPM': 1.3319999999999999}
# Average features for 2015-03-31: {'Acousticness': 0.24100000000000002, 'Danceability': 0.659, 'Energy': 0.634, 'Instrumentalness': 0.001, 'BPM': 1.321}
# Average features for 2015-04-30: {'Acousticness': 0.2, 'Danceability': 0.6509999999999999, 'Energy': 0.6459999999999999, 'Instrumentalness': 0.001, 'BPM': 1.319}
# Average features for 2015-05-31: {'Acousticness': 0.153, 'Danceability': 0.745, 'Energy': 0.639, 'Instrumentalness': 0.0, 'BPM': 1.149}
# Average features for 2015-06-30: {'Acousticness': 0.163, 'Danceability': 0.7290000000000001, 'Energy': 0.643, 'Instrumentalness': 0.0, 'BPM': 1.157}
# Average features for 2015-07-31: {'Acousticness': 0.127, 'Danceability': 0.7759999999999999, 'Energy': 0.623, 'Instrumentalness': 0.0, 'BPM': 1.1909999999999998}
# Average features for 2015-08-31: {'Acousticness': 0.142, 'Danceability': 0.72, 'Energy': 0.65, 'Instrumentalness': 0.0, 'BPM': 1.349}
# Average features for 2015-09-30: {'Acousticness': 0.09, 'Danceability': 0.746, 'Energy': 0.655, 'Instrumentalness': 0.0, 'BPM': 1.324}
# Average features for 2015-10-31: {'Acousticness': 0.073, 'Danceability': 0.726, 'Energy': 0.6829999999999999, 'Instrumentalness': 0.0, 'BPM': 1.3259999999999998}
# Average features for 2015-11-30: {'Acousticness': 0.09699999999999999, 'Danceability': 0.6729999999999999, 'Energy': 0.6829999999999999, 'Instrumentalness': 0.0, 'BPM': 1.226}
# Average features for 2015-12-31: {'Acousticness': 0.188, 'Danceability': 0.6990000000000001, 'Energy': 0.602, 'Instrumentalness': 0.0, 'BPM': 1.177}
# Average features for 2016-01-31: {'Acousticness': 0.14800000000000002, 'Danceability': 0.706, 'Energy': 0.6409999999999999, 'Instrumentalness': 0.0, 'BPM': 1.237}
# Average features for 2016-02-29: {'Acousticness': 0.159, 'Danceability': 0.7170000000000001, 'Energy': 0.613, 'Instrumentalness': 0.0, 'BPM': 1.12}
# Average features for 2016-03-31: {'Acousticness': 0.11, 'Danceability': 0.72, 'Energy': 0.615, 'Instrumentalness': 0.001, 'BPM': 1.141}
# Average features for 2016-04-30: {'Acousticness': 0.1, 'Danceability': 0.652, 'Energy': 0.669, 'Instrumentalness': 0.0, 'BPM': 1.247}
# Average features for 2016-05-31: {'Acousticness': 0.07200000000000001, 'Danceability': 0.69, 'Energy': 0.617, 'Instrumentalness': 0.0, 'BPM': 1.194}
# Average features for 2016-06-30: {'Acousticness': 0.076, 'Danceability': 0.691, 'Energy': 0.601, 'Instrumentalness': 0.002, 'BPM': 1.2570000000000001}
# Average features for 2016-07-31: {'Acousticness': 0.10400000000000001, 'Danceability': 0.746, 'Energy': 0.557, 'Instrumentalness': 0.0, 'BPM': 1.163}
# Average features for 2016-08-31: {'Acousticness': 0.099, 'Danceability': 0.725, 'Energy': 0.59, 'Instrumentalness': 0.002, 'BPM': 1.192}
# Average features for 2016-09-30: {'Acousticness': 0.146, 'Danceability': 0.6890000000000001, 'Energy': 0.595, 'Instrumentalness': 0.002, 'BPM': 1.213}
# Average features for 2016-10-31: {'Acousticness': 0.187, 'Danceability': 0.691, 'Energy': 0.6809999999999999, 'Instrumentalness': 0.001, 'BPM': 1.171}
# Average features for 2016-11-30: {'Acousticness': 0.152, 'Danceability': 0.742, 'Energy': 0.6920000000000001, 'Instrumentalness': 0.001, 'BPM': 1.24}
# Average features for 2016-12-31: {'Acousticness': 0.14400000000000002, 'Danceability': 0.73, 'Energy': 0.67, 'Instrumentalness': 0.001, 'BPM': 1.229}
# Average features for 2017-01-31: {'Acousticness': 0.095, 'Danceability': 0.6940000000000001, 'Energy': 0.631, 'Instrumentalness': 0.001, 'BPM': 1.207}
# Average features for 2017-02-28: {'Acousticness': 0.162, 'Danceability': 0.674, 'Energy': 0.614, 'Instrumentalness': 0.09300000000000001, 'BPM': 1.147}
# Average features for 2017-03-31: {'Acousticness': 0.099, 'Danceability': 0.738, 'Energy': 0.594, 'Instrumentalness': 0.09300000000000001, 'BPM': 1.1540000000000001}
# Average features for 2017-04-30: {'Acousticness': 0.161, 'Danceability': 0.727, 'Energy': 0.606, 'Instrumentalness': 0.013999999999999999, 'BPM': 1.281}
# Average features for 2017-05-31: {'Acousticness': 0.17600000000000002, 'Danceability': 0.6779999999999999, 'Energy': 0.662, 'Instrumentalness': 0.013999999999999999, 'BPM': 1.252}
# Average features for 2017-06-30: {'Acousticness': 0.16899999999999998, 'Danceability': 0.711, 'Energy': 0.631, 'Instrumentalness': 0.013999999999999999, 'BPM': 1.213}
# Average features for 2017-07-31: {'Acousticness': 0.11800000000000001, 'Danceability': 0.69, 'Energy': 0.69, 'Instrumentalness': 0.0, 'BPM': 1.095}
# Average features for 2017-08-31: {'Acousticness': 0.105, 'Danceability': 0.7140000000000001, 'Energy': 0.665, 'Instrumentalness': 0.092, 'BPM': 1.119}
# Average features for 2017-09-30: {'Acousticness': 0.163, 'Danceability': 0.684, 'Energy': 0.691, 'Instrumentalness': 0.092, 'BPM': 1.178}
# Average features for 2017-10-31: {'Acousticness': 0.16699999999999998, 'Danceability': 0.654, 'Energy': 0.6579999999999999, 'Instrumentalness': 0.13699999999999998, 'BPM': 1.192}
# Average features for 2017-11-30: {'Acousticness': 0.18, 'Danceability': 0.706, 'Energy': 0.598, 'Instrumentalness': 0.105, 'BPM': 1.1}
# Average features for 2017-12-31: {'Acousticness': 0.257, 'Danceability': 0.7090000000000001, 'Energy': 0.634, 'Instrumentalness': 0.013000000000000001, 'BPM': 1.079}
# Average features for 2018-01-31: {'Acousticness': 0.132, 'Danceability': 0.738, 'Energy': 0.6729999999999999, 'Instrumentalness': 0.013000000000000001, 'BPM': 1.087}
# Average features for 2018-02-28: {'Acousticness': 0.11900000000000001, 'Danceability': 0.76, 'Energy': 0.679, 'Instrumentalness': 0.0, 'BPM': 1.123}
# Average features for 2018-03-31: {'Acousticness': 0.174, 'Danceability': 0.773, 'Energy': 0.5529999999999999, 'Instrumentalness': 0.0, 'BPM': 1.044}
# Average features for 2018-04-30: {'Acousticness': 0.11699999999999999, 'Danceability': 0.7809999999999999, 'Energy': 0.5720000000000001, 'Instrumentalness': 0.0, 'BPM': 0.9940000000000001}
# Average features for 2018-05-31: {'Acousticness': 0.096, 'Danceability': 0.778, 'Energy': 0.607, 'Instrumentalness': 0.0, 'BPM': 1.0090000000000001}
# Average features for 2018-06-30: {'Acousticness': 0.254, 'Danceability': 0.703, 'Energy': 0.518, 'Instrumentalness': 0.0, 'BPM': 0.9740000000000001}
# Average features for 2018-07-31: {'Acousticness': 0.177, 'Danceability': 0.7240000000000001, 'Energy': 0.516, 'Instrumentalness': 0.006, 'BPM': 0.996}
# Average features for 2018-08-31: {'Acousticness': 0.085, 'Danceability': 0.763, 'Energy': 0.5539999999999999, 'Instrumentalness': 0.006, 'BPM': 1.0490000000000002}
# Average features for 2018-09-30: {'Acousticness': 0.21100000000000002, 'Danceability': 0.723, 'Energy': 0.525, 'Instrumentalness': 0.006, 'BPM': 1.02}
# Average features for 2018-10-31: {'Acousticness': 0.235, 'Danceability': 0.693, 'Energy': 0.575, 'Instrumentalness': 0.006, 'BPM': 1.125}
# Average features for 2018-11-30: {'Acousticness': 0.127, 'Danceability': 0.759, 'Energy': 0.594, 'Instrumentalness': 0.0, 'BPM': 1.1179999999999999}
# Average features for 2018-12-31: {'Acousticness': 0.318, 'Danceability': 0.69, 'Energy': 0.603, 'Instrumentalness': 0.0, 'BPM': 1.125}
# Average features for 2019-01-31: {'Acousticness': 0.11699999999999999, 'Danceability': 0.738, 'Energy': 0.649, 'Instrumentalness': 0.0, 'BPM': 1.254}
# Average features for 2019-02-28: {'Acousticness': 0.11800000000000001, 'Danceability': 0.75, 'Energy': 0.657, 'Instrumentalness': 0.0, 'BPM': 1.232}
# Average features for 2019-03-31: {'Acousticness': 0.142, 'Danceability': 0.7, 'Energy': 0.634, 'Instrumentalness': 0.0, 'BPM': 1.27}
# Average features for 2019-04-30: {'Acousticness': 0.14400000000000002, 'Danceability': 0.743, 'Energy': 0.607, 'Instrumentalness': 0.002, 'BPM': 1.349}
# Average features for 2019-05-31: {'Acousticness': 0.094, 'Danceability': 0.7509999999999999, 'Energy': 0.627, 'Instrumentalness': 0.002, 'BPM': 1.341}
# Average features for 2019-06-30: {'Acousticness': 0.159, 'Danceability': 0.79, 'Energy': 0.618, 'Instrumentalness': 0.0, 'BPM': 1.242}
# Average features for 2019-07-31: {'Acousticness': 0.111, 'Danceability': 0.698, 'Energy': 0.6709999999999999, 'Instrumentalness': 0.0, 'BPM': 1.272}
# Average features for 2019-08-31: {'Acousticness': 0.218, 'Danceability': 0.743, 'Energy': 0.613, 'Instrumentalness': 0.005, 'BPM': 1.176}
# Average features for 2019-09-30: {'Acousticness': 0.228, 'Danceability': 0.731, 'Energy': 0.59, 'Instrumentalness': 0.0, 'BPM': 1.244}
# Average features for 2019-10-31: {'Acousticness': 0.245, 'Danceability': 0.7140000000000001, 'Energy': 0.5820000000000001, 'Instrumentalness': 0.0, 'BPM': 1.272}
# Average features for 2019-11-30: {'Acousticness': 0.239, 'Danceability': 0.725, 'Energy': 0.5920000000000001, 'Instrumentalness': 0.006, 'BPM': 1.147}
# Average features for 2019-12-31: {'Acousticness': 0.419, 'Danceability': 0.66, 'Energy': 0.499, 'Instrumentalness': 0.0, 'BPM': 1.072}
# Average features for 2020-01-31: {'Acousticness': 0.168, 'Danceability': 0.779, 'Energy': 0.589, 'Instrumentalness': 0.006, 'BPM': 1.145}
# Average features for 2020-02-29: {'Acousticness': 0.188, 'Danceability': 0.8190000000000001, 'Energy': 0.565, 'Instrumentalness': 0.0, 'BPM': 1.081}
# Average features for 2020-03-31: {'Acousticness': 0.146, 'Danceability': 0.752, 'Energy': 0.624, 'Instrumentalness': 0.008, 'BPM': 1.172}
# Average features for 2020-04-30: {'Acousticness': 0.175, 'Danceability': 0.812, 'Energy': 0.579, 'Instrumentalness': 0.008, 'BPM': 1.087}
# Average features for 2020-05-31: {'Acousticness': 0.138, 'Danceability': 0.852, 'Energy': 0.5489999999999999, 'Instrumentalness': 0.06, 'BPM': 1.0490000000000002}
# Average features for 2020-06-30: {'Acousticness': 0.084, 'Danceability': 0.81, 'Energy': 0.638, 'Instrumentalness': 0.06, 'BPM': 1.1440000000000001}
# Average features for 2020-07-31: {'Acousticness': 0.191, 'Danceability': 0.6970000000000001, 'Energy': 0.598, 'Instrumentalness': 0.06, 'BPM': 1.3030000000000002}
# Average features for 2020-08-31: {'Acousticness': 0.059000000000000004, 'Danceability': 0.789, 'Energy': 0.6729999999999999, 'Instrumentalness': 0.0, 'BPM': 1.36}
# Average features for 2020-09-30: {'Acousticness': 0.086, 'Danceability': 0.75, 'Energy': 0.685, 'Instrumentalness': 0.0, 'BPM': 1.281}
# Average features for 2020-10-31: {'Acousticness': 0.065, 'Danceability': 0.804, 'Energy': 0.677, 'Instrumentalness': 0.0, 'BPM': 1.215}
# Average features for 2020-11-30: {'Acousticness': 0.12300000000000001, 'Danceability': 0.764, 'Energy': 0.631, 'Instrumentalness': 0.0, 'BPM': 1.1640000000000001}
# Average features for 2020-12-31: {'Acousticness': 0.563, 'Danceability': 0.598, 'Energy': 0.45899999999999996, 'Instrumentalness': 0.0, 'BPM': 1.113}
# Average features for 2021-01-31: {'Acousticness': 0.31, 'Danceability': 0.68, 'Energy': 0.615, 'Instrumentalness': 0.0, 'BPM': 1.057}
# Average features for 2021-02-28: {'Acousticness': 0.28600000000000003, 'Danceability': 0.7440000000000001, 'Energy': 0.5770000000000001, 'Instrumentalness': 0.008, 'BPM': 1.107}
# Average features for 2021-03-31: {'Acousticness': 0.287, 'Danceability': 0.753, 'Energy': 0.455, 'Instrumentalness': 0.008, 'BPM': 1.115}
# Average features for 2021-04-30: {'Acousticness': 0.41100000000000003, 'Danceability': 0.644, 'Energy': 0.475, 'Instrumentalness': 0.008, 'BPM': 1.1840000000000002}
# Average features for 2021-05-31: {'Acousticness': 0.358, 'Danceability': 0.622, 'Energy': 0.45, 'Instrumentalness': 0.006, 'BPM': 1.1320000000000001}
# Average features for 2021-06-30: {'Acousticness': 0.318, 'Danceability': 0.643, 'Energy': 0.466, 'Instrumentalness': 0.006, 'BPM': 1.21}
# Average features for 2021-07-31: {'Acousticness': 0.20600000000000002, 'Danceability': 0.728, 'Energy': 0.504, 'Instrumentalness': 0.006, 'BPM': 1.158}
# Average features for 2021-08-31: {'Acousticness': 0.358, 'Danceability': 0.657, 'Energy': 0.493, 'Instrumentalness': 0.006, 'BPM': 1.235}
# Average features for 2021-09-30: {'Acousticness': 0.278, 'Danceability': 0.667, 'Energy': 0.49200000000000005, 'Instrumentalness': 0.086, 'BPM': 1.2329999999999999}
# Average features for 2021-10-31: {'Acousticness': 0.18, 'Danceability': 0.722, 'Energy': 0.523, 'Instrumentalness': 0.0, 'BPM': 1.22}
# Average features for 2021-11-30: {'Acousticness': 0.168, 'Danceability': 0.6679999999999999, 'Energy': 0.5660000000000001, 'Instrumentalness': 0.0, 'BPM': 1.1640000000000001}
# Average features for 2021-12-31: {'Acousticness': 0.469, 'Danceability': 0.622, 'Energy': 0.485, 'Instrumentalness': 0.057, 'BPM': 1.1909999999999998}
# Average features for 2022-01-31: {'Acousticness': 0.187, 'Danceability': 0.662, 'Energy': 0.589, 'Instrumentalness': 0.153, 'BPM': 1.235}
# Average features for 2022-02-28: {'Acousticness': 0.20600000000000002, 'Danceability': 0.6920000000000001, 'Energy': 0.618, 'Instrumentalness': 0.057, 'BPM': 1.298}
# Average features for 2022-03-31: {'Acousticness': 0.303, 'Danceability': 0.6970000000000001, 'Energy': 0.523, 'Instrumentalness': 0.14300000000000002, 'BPM': 1.3319999999999999}
# Average features for 2022-04-30: {'Acousticness': 0.214, 'Danceability': 0.6709999999999999, 'Energy': 0.6509999999999999, 'Instrumentalness': 0.0, 'BPM': 1.204}
# Average features for 2022-05-31: {'Acousticness': 0.203, 'Danceability': 0.653, 'Energy': 0.654, 'Instrumentalness': 0.0, 'BPM': 1.114}
# Average features for 2022-06-30: {'Acousticness': 0.326, 'Danceability': 0.718, 'Energy': 0.541, 'Instrumentalness': 0.0, 'BPM': 1.15}
# Average features for 2022-07-31: {'Acousticness': 0.20600000000000002, 'Danceability': 0.6659999999999999, 'Energy': 0.6679999999999999, 'Instrumentalness': 0.0, 'BPM': 1.206}
# Average features for 2022-08-31: {'Acousticness': 0.217, 'Danceability': 0.66, 'Energy': 0.629, 'Instrumentalness': 0.0, 'BPM': 1.093}
# Average features for 2022-09-30: {'Acousticness': 0.18899999999999997, 'Danceability': 0.679, 'Energy': 0.594, 'Instrumentalness': 0.0, 'BPM': 1.0979999999999999}
# Average features for 2022-10-31: {'Acousticness': 0.22899999999999998, 'Danceability': 0.612, 'Energy': 0.66, 'Instrumentalness': 0.022000000000000002, 'BPM': 1.136}
# Average features for 2022-11-30: {'Acousticness': 0.284, 'Danceability': 0.7340000000000001, 'Energy': 0.537, 'Instrumentalness': 0.0, 'BPM': 1.047}
# Average features for 2022-12-31: {'Acousticness': 0.447, 'Danceability': 0.6659999999999999, 'Energy': 0.495, 'Instrumentalness': 0.0, 'BPM': 1.1640000000000001}
# Average features for 2023-01-31: {'Acousticness': 0.23399999999999999, 'Danceability': 0.784, 'Energy': 0.536, 'Instrumentalness': 0.0, 'BPM': 1.165}
# Average features for 2023-02-28: {'Acousticness': 0.252, 'Danceability': 0.741, 'Energy': 0.565, 'Instrumentalness': 0.0, 'BPM': 1.218}
# Average features for 2023-03-31: {'Acousticness': 0.366, 'Danceability': 0.735, 'Energy': 0.5710000000000001, 'Instrumentalness': 0.0, 'BPM': 1.114}
# Average features for 2023-04-30: {'Acousticness': 0.348, 'Danceability': 0.7709999999999999, 'Energy': 0.595, 'Instrumentalness': 0.0, 'BPM': 1.167}
# Average features for 2023-05-31: {'Acousticness': 0.34, 'Danceability': 0.763, 'Energy': 0.542, 'Instrumentalness': 0.0, 'BPM': 1.111}
# Average features for 2023-06-30: {'Acousticness': 0.401, 'Danceability': 0.759, 'Energy': 0.5529999999999999, 'Instrumentalness': 0.0, 'BPM': 1.091}
# Average features for 2023-07-31: {'Acousticness': 0.27699999999999997, 'Danceability': 0.594, 'Energy': 0.631, 'Instrumentalness': 0.08900000000000001, 'BPM': 1.318}
# Average features for 2023-08-31: {'Acousticness': 0.377, 'Danceability': 0.601, 'Energy': 0.5760000000000001, 'Instrumentalness': 0.08900000000000001, 'BPM': 1.251}
# Average features for 2023-09-30: {'Acousticness': 0.314, 'Danceability': 0.5579999999999999, 'Energy': 0.608, 'Instrumentalness': 0.08900000000000001, 'BPM': 1.2770000000000001}
# Average features for 2023-10-31: {'Acousticness': 0.376, 'Danceability': 0.64, 'Energy': 0.624, 'Instrumentalness': 0.0, 'BPM': 1.319}
# Average features for 2023-11-30: {'Acousticness': 0.294, 'Danceability': 0.624, 'Energy': 0.5489999999999999, 'Instrumentalness': 0.18100000000000002, 'BPM': 1.056}
# Average features for 2023-12-31: {'Acousticness': 0.52, 'Danceability': 0.647, 'Energy': 0.46399999999999997, 'Instrumentalness': 0.006, 'BPM': 1.153}

# %%
df.head() # let's check format
# Out:
#             Acousticness  Danceability  Energy  Instrumentalness    BPM
# 2010-01-31         0.198         0.739   0.710             0.086  1.230
# 2010-02-28         0.130         0.794   0.570             0.000  1.090
# 2010-03-31         0.175         0.730   0.739             0.085  1.213
# 2010-04-30         0.143         0.727   0.714             0.000  1.182
# 2010-05-31         0.173         0.685   0.779             0.097  1.134

# %%
import plotly.express as px

# Assuming df is your DataFrame containing the audio features data
# Plotting each feature over time
df.reset_index(inplace=True)  # Reset index to use 'index' as a column for months

# Create the line plot
fig = px.line(df, x='index', y=df.columns[1:],  # 'index' is the month_str (x-axis), and features as y-axis
              labels={'index': 'Month', 'value': 'Feature Value (in decimal)'},  # Axis labels
              title="Audio Features Over Time (2010-2023)",
              markers=True)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9e53e93b-c868-4135-bb9e-1b1c7c1a63ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e53e93b-c868-4135-bb9e-1b1c7c1a63ca")) {                    Plotly.newPlot(                        "9e53e93b-c868-4135-bb9e-1b1c7c1a63ca",                        [{"hovertemplate":"variable=Acousticness\u003cbr\u003eMonth=%{x}\u003cbr\u003eFeature Value (in decimal)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Acousticness","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Acousticness","orientation":"v","showlegend":true,"x":["2010-01-31","2010-02-28","2010-03-31","2010-04-30","2010-05-31","2010-06-30","2010-07-31","2010-08-31","2010-09-30","2010-10-31","2010-11-30","2010-12-31","2011-01-31","2011-02-28","2011-03-31","2011-04-30","2011-05-31","2011-06-30","2011-07-31","2011-08-31","2011-09-30","2011-10-31","2011-11-30","2011-12-31","2012-01-31","2012-02-29","2012-03-31","2012-04-30","2012-05-31","2012-06-30","2012-07-31","2012-08-31","2012-09-30","2012-10-31","2012-11-30","2012-12-31","2013-01-31","2013-02-28","2013-03-31","2013-04-30","2013-05-31","2013-06-30","2013-07-31","2013-08-31","2013-09-30","2013-10-31","2013-11-30","2013-12-31","2014-01-31","2014-02-28","2014-03-31","2014-04-30","2014-05-31","2014-06-30","2014-07-31","2014-08-31","2014-09-30","2014-10-31","2014-11-30","2014-12-31","2015-01-31","2015-02-28","2015-03-31","2015-04-30","2015-05-31","2015-06-30","2015-07-31","2015-08-31","2015-09-30","2015-10-31","2015-11-30","2015-12-31","2016-01-31","2016-02-29","2016-03-31","2016-04-30","2016-05-31","2016-06-30","2016-07-31","2016-08-31","2016-09-30","2016-10-31","2016-11-30","2016-12-31","2017-01-31","2017-02-28","2017-03-31","2017-04-30","2017-05-31","2017-06-30","2017-07-31","2017-08-31","2017-09-30","2017-10-31","2017-11-30","2017-12-31","2018-01-31","2018-02-28","2018-03-31","2018-04-30","2018-05-31","2018-06-30","2018-07-31","2018-08-31","2018-09-30","2018-10-31","2018-11-30","2018-12-31","2019-01-31","2019-02-28","2019-03-31","2019-04-30","2019-05-31","2019-06-30","2019-07-31","2019-08-31","2019-09-30","2019-10-31","2019-11-30","2019-12-31","2020-01-31","2020-02-29","2020-03-31","2020-04-30","2020-05-31","2020-06-30","2020-07-31","2020-08-31","2020-09-30","2020-10-31","2020-11-30","2020-12-31","2021-01-31","2021-02-28","2021-03-31","2021-04-30","2021-05-31","2021-06-30","2021-07-31","2021-08-31","2021-09-30","2021-10-31","2021-11-30","2021-12-31","2022-01-31","2022-02-28","2022-03-31","2022-04-30","2022-05-31","2022-06-30","2022-07-31","2022-08-31","2022-09-30","2022-10-31","2022-11-30","2022-12-31","2023-01-31","2023-02-28","2023-03-31","2023-04-30","2023-05-31","2023-06-30","2023-07-31","2023-08-31","2023-09-30","2023-10-31","2023-11-30","2023-12-31"],"xaxis":"x","y":[0.198,0.13,0.175,0.14300000000000002,0.17300000000000001,0.187,0.14800000000000002,0.15,0.158,0.13699999999999998,0.081,0.138,0.15,0.10800000000000001,0.188,0.201,0.223,0.17600000000000002,0.23399999999999999,0.195,0.24600000000000002,0.298,0.255,0.198,0.14400000000000002,0.192,0.145,0.309,0.304,0.26899999999999996,0.168,0.257,0.152,0.168,0.12300000000000001,0.066,0.045,0.226,0.23399999999999999,0.242,0.252,0.131,0.134,0.192,0.19,0.14800000000000002,0.129,0.16,0.121,0.087,0.08199999999999999,0.152,0.182,0.129,0.067,0.094,0.106,0.10800000000000001,0.126,0.193,0.22699999999999998,0.319,0.24100000000000002,0.2,0.153,0.163,0.127,0.142,0.09,0.073,0.09699999999999999,0.188,0.14800000000000002,0.159,0.11,0.1,0.07200000000000001,0.076,0.10400000000000001,0.099,0.146,0.187,0.152,0.14400000000000002,0.095,0.162,0.099,0.161,0.17600000000000002,0.16899999999999998,0.11800000000000001,0.105,0.163,0 ...
